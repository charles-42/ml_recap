# %%
import pandas as pd
df_features = pd.read_csv("features.csv")
df_tracks = pd.read_csv("tracks.csv")

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53495 entries, 0 to 53494
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53495 non-null  int64
#  1   id          53495 non-null  object
#  2   popularity  53495 non-null  int64
#  3   names       53495 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 1.6+ MB

# %%
df_final = df_features.merge(df_tracks,on="id")

# %%
df_propre = df_final.drop(columns=['Unnamed: 0_x', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'type',
        'Unnamed: 0_y',  'names'])

# %%
df_propre.head()
# Out:
#    danceability   energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.339  0.00572   11   -32.309     0       0.0378         0.986
# 1         0.303  0.00958    8   -28.556     1       0.0540         0.991
# 2         0.218  0.00352    1   -39.627     1       0.0515         0.992
# 3         0.307  0.00229    1   -34.977     1       0.0519         0.992
# 4         0.208  0.01200    8   -29.933     1       0.0422         0.987
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0             0.923     0.103   0.0616   72.700       198650               3
# 1             0.953     0.109   0.2120   72.204       264845               5
# 2             0.951     0.139   0.1920   68.610       335542               4
# 3             0.931     0.098   0.2810   67.775       283280               5
# 4             0.919     0.100   0.0391  175.159       257217               3
#
#    popularity
# 0          62
# 1          58
# 2          58
# 3          60
# 4          58

# %%
from pycaret.regression import setup

# %%
exp_reg101 = setup(data = df_propre, target = 'popularity', session_id=123)
# Out:
# <style type="text/css">
# #T_9c5ba_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9c5ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c5ba_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9c5ba_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c5ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c5ba_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_9c5ba_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c5ba_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9c5ba_row1_col1" class="data row1 col1" >popularity</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9c5ba_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_9c5ba_row2_col1" class="data row2 col1" >(59079, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9c5ba_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_9c5ba_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9c5ba_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_9c5ba_row4_col1" class="data row4 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9c5ba_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_9c5ba_row5_col1" class="data row5 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9c5ba_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_9c5ba_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9c5ba_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_9c5ba_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9c5ba_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_9c5ba_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9c5ba_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_9c5ba_row9_col1" class="data row9 col1" >(41355, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9c5ba_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_9c5ba_row10_col1" class="data row10 col1" >(17724, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9c5ba_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_9c5ba_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9c5ba_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_9c5ba_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9c5ba_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_9c5ba_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9c5ba_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_9c5ba_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9c5ba_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_9c5ba_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9c5ba_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_9c5ba_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9c5ba_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_9c5ba_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9c5ba_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_9c5ba_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9c5ba_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_9c5ba_row19_col1" class="data row19 col1" >95fa</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9c5ba_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_9c5ba_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9c5ba_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_9c5ba_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_9c5ba_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_9c5ba_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_9c5ba_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_9c5ba_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_9c5ba_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_9c5ba_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_9c5ba_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_9c5ba_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_9c5ba_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_9c5ba_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_9c5ba_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_9c5ba_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_9c5ba_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_9c5ba_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_9c5ba_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_9c5ba_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ba_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_9c5ba_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_9c5ba_row30_col1"

# %%
from pycaret.regression import compare_models
best = compare_models(exclude = ['ransac'])
# Out:
# <style type="text/css">
# #T_8bd6f th {
#   text-align: left;
# }
# #T_8bd6f_row0_col0, #T_8bd6f_row0_col6, #T_8bd6f_row1_col0, #T_8bd6f_row1_col1, #T_8bd6f_row1_col2, #T_8bd6f_row1_col3, #T_8bd6f_row1_col4, #T_8bd6f_row1_col5, #T_8bd6f_row1_col6, #T_8bd6f_row2_col0, #T_8bd6f_row2_col1, #T_8bd6f_row2_col2, #T_8bd6f_row2_col3, #T_8bd6f_row2_col4, #T_8bd6f_row2_col5, #T_8bd6f_row2_col6, #T_8bd6f_row3_col0, #T_8bd6f_row3_col1, #T_8bd6f_row3_col2, #T_8bd6f_row3_col3, #T_8bd6f_row3_col4, #T_8bd6f_row3_col5, #T_8bd6f_row3_col6, #T_8bd6f_row4_col0, #T_8bd6f_row4_col1, #T_8bd6f_row4_col2, #T_8bd6f_row4_col3, #T_8bd6f_row4_col4, #T_8bd6f_row4_col5, #T_8bd6f_row4_col6, #T_8bd6f_row5_col0, #T_8bd6f_row5_col1, #T_8bd6f_row5_col2, #T_8bd6f_row5_col3, #T_8bd6f_row5_col4, #T_8bd6f_row5_col5, #T_8bd6f_row5_col6, #T_8bd6f_row6_col0, #T_8bd6f_row6_col1, #T_8bd6f_row6_col2, #T_8bd6f_row6_col3, #T_8bd6f_row6_col4, #T_8bd6f_row6_col5, #T_8bd6f_row6_col6, #T_8bd6f_row7_col0, #T_8bd6f_row7_col1, #T_8bd6f_row7_col2, #T_8bd6f_row7_col3, #T_8bd6f_row7_col4, #T_8bd6f_row7_col5, #T_8bd6f_row7_col6, #T_8bd6f_row8_col0, #T_8bd6f_row8_col1, #T_8bd6f_row8_col2, #T_8bd6f_row8_col3, #T_8bd6f_row8_col4, #T_8bd6f_row8_col5, #T_8bd6f_row8_col6, #T_8bd6f_row9_col0, #T_8bd6f_row9_col1, #T_8bd6f_row9_col2, #T_8bd6f_row9_col3, #T_8bd6f_row9_col4, #T_8bd6f_row9_col5, #T_8bd6f_row9_col6, #T_8bd6f_row10_col0, #T_8bd6f_row10_col1, #T_8bd6f_row10_col2, #T_8bd6f_row10_col3, #T_8bd6f_row10_col4, #T_8bd6f_row10_col5, #T_8bd6f_row10_col6, #T_8bd6f_row11_col0, #T_8bd6f_row11_col1, #T_8bd6f_row11_col2, #T_8bd6f_row11_col3, #T_8bd6f_row11_col4, #T_8bd6f_row11_col5, #T_8bd6f_row11_col6, #T_8bd6f_row12_col0, #T_8bd6f_row12_col1, #T_8bd6f_row12_col2, #T_8bd6f_row12_col3, #T_8bd6f_row12_col4, #T_8bd6f_row12_col5, #T_8bd6f_row12_col6, #T_8bd6f_row13_col0, #T_8bd6f_row13_col1, #T_8bd6f_row13_col2, #T_8bd6f_row13_col3, #T_8bd6f_row13_col4, #T_8bd6f_row13_col5, #T_8bd6f_row13_col6, #T_8bd6f_row14_col0, #T_8bd6f_row14_col1, #T_8bd6f_row14_col2, #T_8bd6f_row14_col3, #T_8bd6f_row14_col4, #T_8bd6f_row14_col5, #T_8bd6f_row14_col6, #T_8bd6f_row15_col0, #T_8bd6f_row15_col1, #T_8bd6f_row15_col2, #T_8bd6f_row15_col3, #T_8bd6f_row15_col4, #T_8bd6f_row15_col5, #T_8bd6f_row15_col6, #T_8bd6f_row16_col0, #T_8bd6f_row16_col1, #T_8bd6f_row16_col2, #T_8bd6f_row16_col3, #T_8bd6f_row16_col4, #T_8bd6f_row16_col5, #T_8bd6f_row17_col0, #T_8bd6f_row17_col1, #T_8bd6f_row17_col2, #T_8bd6f_row17_col3, #T_8bd6f_row17_col4, #T_8bd6f_row17_col5, #T_8bd6f_row17_col6 {
#   text-align: left;
# }
# #T_8bd6f_row0_col1, #T_8bd6f_row0_col2, #T_8bd6f_row0_col3, #T_8bd6f_row0_col4, #T_8bd6f_row0_col5, #T_8bd6f_row16_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8bd6f_row0_col7, #T_8bd6f_row1_col7, #T_8bd6f_row2_col7, #T_8bd6f_row3_col7, #T_8bd6f_row4_col7, #T_8bd6f_row5_col7, #T_8bd6f_row6_col7, #T_8bd6f_row7_col7, #T_8bd6f_row8_col7, #T_8bd6f_row9_col7, #T_8bd6f_row10_col7, #T_8bd6f_row11_col7, #T_8bd6f_row12_col7, #T_8bd6f_row13_col7, #T_8bd6f_row14_col7, #T_8bd6f_row16_col7, #T_8bd6f_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8bd6f_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8bd6f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bd6f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8bd6f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8bd6f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8bd6f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8bd6f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8bd6f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8bd6f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_8bd6f_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bd6f_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_8bd6f_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_8bd6f_row0_col1" class="data row0 col1" >10.4897</td>
#       <td id="T_8bd6f_row0_col2" class="data row0 col2" >200.5905</td>
#       <td id="T_8bd6f_row0_col3" class="data row0 col3" >14.1624</td>
#       <td id="T_8bd6f_row0_col4" class="data row0 col4" >0.6575</td>
#       <td id="T_8bd6f_row0_col5" class="data row0 col5" >1.4905</td>
#       <td id="T_8bd6f_row0_col6" class="data row0 col6" >1.4570</td>
#       <td id="T_8bd6f_row0_col7" class="data row0 col7" >17.1070</td>
#     </tr>
#     <tr>
#       <th id="T_8bd6f_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_8bd6f_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_8bd6f_row1_col1" class="data row1 col1" >10.6777</td>
#       <td id="T_8bd6f_row1_col2" class="data row1 col2" >201.6188</td>
#       <td id="T_8bd6f_row1_col3" class="data row1 col3" >14.1985</td>
#       <td id="T_8bd6f_row1_col4" class="data row1 col4" >0.6557</td>
#       <td id="T_8bd6f_row1_col5" class="data row1 col5" >1.4916</td>
#       <td id="T_8bd6f_row1_col6" class="data row1 col6" >1.4756</td>
#       <td id="T_8bd6f_row1_col7" class="data row1 col7" >27.7350</td>
#     </tr>
#     <tr>
#       <th id="T_8bd6f_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_8bd6f_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8bd6f_row2_col1" class="data row2 col1" >12.7836</td>
#       <td id="T_8bd6f_row2_col2" class="data row2 col2" >257.9055</td>
#       <td id="T_8bd6f_row2_col3" class="data row2 col3" >16.0589</td>
#       <td id="T_8bd6f_row2_col4" class="data row2 col4" >0.5596</td>
#       <td id="T_8bd6f_row2_col5" class="data row2 col5" >1.5411</td>
#       <td id="T_8bd6f_row2_col6" class="data row2 col6" >1.5871</td>
#       <td id="T_8bd6f_row2_col7" class="data row2 col7" >0.5080</td>
#     </tr>
#     <tr>
#       <th id="T_8bd6f_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_8bd6f_row3_col0" class="data row3 col0" >K Neighbors Regressor</td>
#       <td id="T_8bd6f_row3_col1" class="data row3 col1" >13.5302</td>
#       <td id="T_8bd6f_row3_col2" class="data row3 col2" >334.2987</td>
#       <td id="T_8bd6f_row3_col3" class="data row3 col3" >18.2831</td>
#       <td id="T_8bd6f_row3_col4" class="data row3 col4" >0.4292</td>
#       <td id="T_8bd6f_row3_col5" class="data row3 col5" >1.6336</td>
#       <td id="T_8bd6f_row3_col6" class="data row3 col6" >1.7589</td>
#       <td id="T_8bd6f_row3_col7" class="data row3 col7" >0.2010</td>
#     </tr>
#     <tr>
#       <th id="T_8bd6f_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_8bd6f_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_8bd6f_row4_col1" class="data row4 col1" >14.9599</td>
#       <td id="T_8bd6f_row4_col2" class="data row4 col2" >351.1023</td>
#       <td id="T_8bd6f_row4_col3" class="data row4 col3" >18.7370</td>
#       <td id="T_8bd6f_row4_col4" class="data row4 col4" >0.4006</td>
#       <td id="T_8bd6f_row4_col5" class="data row4 col5" >1.6039</td>
#       <td id="T_8bd6f_row4_col6" class="data row4 col6" >1.7999</td>
#       <td id="T_8bd6f_row4_col7" class="data row4 col7" >8.6040</td>
#     </tr>
#     <tr>
#       <th id="T_8bd6f_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_8bd6f_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_8bd6f_row5_col1" class="data row5 col1" >13.4390</td>
#       <td id="T_8bd6f_row5_col2" class="data row5 col2" >414.9649</td>
#       <td id="T_8bd6f_row5_col3" class="data row5 col3" >20.3704</td>
#       <td id="T_8bd6f_row5_col4" class="data row5 col4" >0.2914</td>
#       <td id="T_8bd6f_row5_col5" class="data row5 col5" >1.7649</td>
#       <td id="T_8bd6f_row5_col6" class="data row5 col6" >1.7924</td>
#       <td id="T_8bd6f_row5_col7" class="data row5 col7" >0.4730</td>
#     </tr>
#     <tr>
